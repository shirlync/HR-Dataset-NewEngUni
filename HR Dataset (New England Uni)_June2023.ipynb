# %%
import pandas as pd

pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv ('C:\\Users\\shirl\\OneDrive\\Desktop\\Projects\\HR dataset_June2023\\HRDataset_v14.csv')

# %%
df.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  Termd  \
# 0            1       5            4                       0   62506      0
# 1            5       3            3                       0  104437      1
# 2            5       5            3                       0   64955      1
# 3            1       5            3                       0   64991      0
# 4            5       5            3                       0   50825      1
#
# ...

# %%
print('Missing Value Counts for Each Column\n' + '='*36)

print(df.isnull().sum())
# Out:
# Missing Value Counts for Each Column
# ...
# Employee_Name                   0
# EmpID                           0
# MarriedID                       0
# MaritalStatusID                 0
# GenderID                        0
# EmpStatusID                     0
# DeptID                          0
# PerfScoreID                     0
# FromDiversityJobFairID          0
# Salary                          0
# Termd                           0
# PositionID                      0
# Position                        0
# State                           0
# Zip                             0
# DOB                             0
# Sex                             0
# MaritalDesc                     0
# CitizenDesc                     0
# HispanicLatino                  0
# RaceDesc                        0
# DateofHire                      0
# DateofTermination             207
# TermReason                      0
# EmploymentStatus                0
# Department                      0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311 entries, 0 to 310
# Data columns (total 36 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Employee_Name               311 non-null    object
#  1   EmpID                       311 non-null    int64
#  2   MarriedID                   311 non-null    int64
#  3   MaritalStatusID             311 non-null    int64
#  4   GenderID                    311 non-null    int64
#  5   EmpStatusID                 311 non-null    int64
#  6   DeptID                      311 non-null    int64
#  7   PerfScoreID                 311 non-null    int64
#  8   FromDiversityJobFairID      311 non-null    int64
#  9   Salary                      311 non-null    int64
#  10  Termd                       311 non-null    int64
#  11  PositionID                  311 non-null    int64
#  12  Position                    311 non-null    object
# ...

# %%
print('Number of duplicates :', df.duplicated().sum())

# Findings: 
# The dataset has data of 311 employees
# 104 out of 311 employees have left the company, and 207 employees are still employed
# There are no duplicated data in the dataset
# Out:
# Number of duplicates : 0

# %%
# Convert 'DOB' column to datetime
df['DOB'] = pd.to_datetime(df['DOB'])

# Filter rows where the year of 'DOB' is greater than 2000
filtered_df = df.query('@df.DOB.dt.year > 2000')

# Sort and get unique years
unique_years = filtered_df.DOB.dt.year.sort_values().unique()

# %%
# Converted DOB to datetime format via Pandas before 
df.query('@df.DOB.dt.year > 2000').DOB.dt.year.sort_values().unique()
# Out:
# array([2051, 2052, 2053, 2054, 2055, 2058, 2059, 2061, 2063, 2064, 2065,
#        2066, 2067, 2068, 2069, 2070, 2071, 2072], dtype=int64)

# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
from plotly import __version__ as pvm

rpt = pd.read_csv('C:/Users/shirl/OneDrive/Desktop/Projects/HR dataset_June2023/HR_PythonHeatMap_June2023 v2.csv')

# %%
rpt.head()
# Out:
#               Employee_Name  EmpID  Salary  Termd  EngagementSurvey  \
# 0       Adinolfi, Wilson  K  10026   62506      0              4.60
# 1  Ait Sidi, Karthikeyan     10084  104437      1              4.96
# 2         Akinkuolie, Sarah  10196   64955      1              3.02
# 3              Alagbe,Trina  10088   64991      0              4.84
# 4          Anderson, Carol   10069   50825      1              5.00
#
#    EmpSatisfaction  SpecialProjectsCount  DaysLateLast30  Absences
# 0                5                     0               0         1
# 1                3                     6               0        17
# 2                3                     0               0         3
# 3                5                     0               0        15
# 4                4                     0               0         2

# %%
rpt.describe()
# Out:
#               EmpID         Salary       Termd  EngagementSurvey  \
# count    311.000000     311.000000  311.000000        311.000000
# mean   10156.000000   69020.684887    0.334405          4.110000
# std       89.922189   25156.636930    0.472542          0.789938
# min    10001.000000   45046.000000    0.000000          1.120000
# 25%    10078.500000   55501.500000    0.000000          3.690000
# 50%    10156.000000   62810.000000    0.000000          4.280000
# 75%    10233.500000   72036.000000    1.000000          4.700000
# max    10311.000000  250000.000000    1.000000          5.000000
#
#        EmpSatisfaction  SpecialProjectsCount  DaysLateLast30    Absences
# count       311.000000            311.000000      311.000000  311.000000
# mean          3.890675              1.218650        0.414791   10.237942
# std           0.909241              2.349421        1.294519    5.852596
# min           1.000000              0.000000        0.000000    1.000000
# ...

# %%
plt.rcParams['figure.figsize'] = (15, 10)
plt.rcParams.update({'font.size': 13})

sb.set(font_scale = 1.5)
sb.set_style(style='white')

sb.heatmap(rpt.corr(numeric_only=True), annot=True, linewidth=1).set_title('Annotated Correlation Matrix of Combined Dataset')
# Out:
# Text(0.5, 1.0, 'Annotated Correlation Matrix of Combined Dataset')
